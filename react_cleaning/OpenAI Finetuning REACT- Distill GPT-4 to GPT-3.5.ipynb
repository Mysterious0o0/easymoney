# %% [markdown]
# # OpenAI Finetuning REACT- Distill GPT-4 to GPT-3.5
#
# In this notebook, we walk through an example of fine-tuning gpt-3.5-turbo.
#
# Specifically, we attempt to distill GPT-4's knowledge, by generating training data with GPT-4 to then fine-tune GPT-3.5.
#
# All training data is generated using two different sections of our index data, creating both a training and evalution set.
#
# We then finetune with our `OpenAIFinetuneEngine` wrapper abstraction.
#
# Evaluation is done using the `ragas` library, which we will detail later on.

# %%
# !pip install llama-index
# Out:
# Collecting llama-index
#   Downloading llama_index-0.9.9-py3-none-any.whl (914 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.3/914.3 kB 16.3 MB/s eta 0:00:00
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index) (2.0.23)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.8.6)
# Collecting aiostream<0.6.0,>=0.5.2 (from llama-index)
#   Downloading aiostream-0.5.2-py3-none-any.whl (39 kB)
# Collecting beautifulsoup4<5.0.0,>=4.12.2 (from llama-index)
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 21.0 MB/s eta 0:00:00
# Collecting dataclasses-json (from llama-index)
#   Downloading dataclasses_json-0.6.3-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (2023.6.0)
# Collecting httpx (from llama-index)
#   Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.5.8)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.23.5)
# Collecting openai>=1.1.0 (from llama-index)
#   Downloading openai-1.3.6-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index) (1.5.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (8.2.3)
# Collecting tiktoken>=0.3.3 (from llama-index)
#   Downloading tiktoken-0.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index) (4.5.0)
# Collecting typing-inspect>=0.8.0 (from llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index) (1.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.2->llama-index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2.9.3->llama-index) (1.14.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index) (4.66.1)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.1.0->llama-index) (1.7.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.1.0->llama-index) (1.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index) (2023.7.22)
# Collecting httpcore==1.* (from httpx->llama-index)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index) (3.4)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->llama-index)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index) (3.0.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index) (2023.3.post1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai>=1.1.0->llama-index) (1.1.3)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index) (23.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->llama-index) (1.16.0)
# Installing collected packages: mypy-extensions, marshmallow, h11, deprecated, beautifulsoup4, aiostream, typing-inspect, tiktoken, httpcore, httpx, dataclasses-json, openai, llama-index
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# Successfully installed aiostream-0.5.2 beautifulsoup4-4.12.2 dataclasses-json-0.6.3 deprecated-1.2.14 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 llama-index-0.9.9 marshmallow-3.20.1 mypy-extensions-1.0.0 openai-1.3.6 tiktoken-0.5.1 typing-inspect-0.9.0

# %%
# !pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-3.17.1-py3-none-any.whl (277 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.6/277.6 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-3.17.1

# %%
import os
import openai
from llama_index import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    ServiceContext,
    load_index_from_storage,
)
from llama_index.llms import OpenAI

from llama_index.tools import QueryEngineTool, ToolMetadata

# %% [markdown]
# ## Data Setup
#
# Here, we first down load the PDF that we will use to generate training data.

# %% [markdown]
# The next step is generating a training and eval dataset.
#
# We will generate 40 questions on different sections of the PDF we downloaded.
#
# We can use GPT-3.5 on the eval questions to get our baseline performance.
#
# Then, we will use GPT-4 on the train questions to generate our training data. The training data will be collected with out `OpenAIFineTuningHandler`.
#
# This step is entirely optional if you don't want to spend the time/tokens -- the eval and training questions are also provided in this folder, as well as the training data!

# %% [markdown]
# ### Train Generation

# %%
llm = OpenAI(temperature=0, model="gpt-3.5-turbo-0613")
# llm = OpenAI(temperature=0, model="gpt-4-0613")
service_context = ServiceContext.from_defaults(llm=llm)

gpt_35_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-3.5-turbo-0613", temperature=0.3)
)
gpt4_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-4-0613", temperature=0.3)
)

try:
    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/march"
    )
    march_index = load_index_from_storage(storage_context)

    index_loaded = True
except:
    index_loaded = False


if not index_loaded:
    # load data
    march_docs = SimpleDirectoryReader(
        input_files=["两种有效的ukulele音阶记忆法.md"]
    ).load_data()


    # build index
    march_index = VectorStoreIndex.from_documents(
        march_docs, service_context=service_context
    )


    # persist index
    march_index.storage_context.persist(persist_dir="./storage/march")

# %%
march_engine = march_index.as_query_engine(
    similarity_top_k=3, service_context=service_context
)
from llama_index.tools.query_engine import QueryEngineTool


query_tool_sept = QueryEngineTool.from_defaults(
    query_engine=march_engine,
    name="music_theory_query",
    description=(
        f"提供关于乐理检索的知识库"
        f" About ukulele Performance Techniques"
    ),
)


query_engine_tools = [query_tool_sept]

# %%
from llama_index.agent import ReActAgent
from llama_index.llms import OpenAI

llm = OpenAI(model="gpt-3.5-turbo-0613")
# llm = OpenAI(model="gpt-4-0613")
base_agent = ReActAgent.from_tools(query_engine_tools, llm=llm, verbose=True)

# %%
from llama_index.evaluation import DatasetGenerator


base_question_gen_query = (
  "你是一名教师/教授，你的任务是安排一次测验/考试。"
  "使用音乐理论教材提交的文件中提供的上下文， 制定一些"
  "关于尤克里里的表演技巧，"
  "关于ukulele的表演技巧。"
  "一个从中捕捉到重要事实的问题上下文，"
  "将问题限制在所提供的上下文信息内."

)
dataset_generator = DatasetGenerator.from_documents(
    march_docs,
    question_gen_query=base_question_gen_query,
    service_context=gpt_35_context,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/llama_index/evaluation/dataset_generation.py:187: DeprecationWarning: Call to deprecated class DatasetGenerator. (Deprecated in favor of `RagDatasetGenerator` which should be used instead.)
#   return cls(

# %%
import asyncio
import sys
import nest_asyncio
nest_asyncio.apply()

questions = dataset_generator.generate_questions_from_nodes(num=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/llama_index/evaluation/dataset_generation.py:282: DeprecationWarning: Call to deprecated class QueryResponseDataset. (Deprecated in favor of `LabelledRagDataset` which should be used instead.)
#   return QueryResponseDataset(queries=queries, responses=responses_dict)

# %%
print(len(questions))
questions
# Out:
# 20
# ['在ukulele的调弦中，第一弦到第四弦的字母分别是什么？',
#  '将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？',
#  '根据全音和半音的关系，如何在指板上填满C调的音阶？',
#  '降D调的指板图相当于将C调的音阶整体往下移了几格？',
#  '在降D调的指板图中，do在原来的位置上是哪根弦的空弦？',
#  '在降D调的指板图中，do向下移一个格后，变成了哪根弦的一品？',
#  '在降D调的指板图中，do向下移一个格后，它的音名可以是哪两个？',
#  '方法一中提到的指型记忆适用于哪些琴弦？',
#  '在方法一中，列出了哪些琴弦的音阶？',
#  '请描述一下方法一中的指型记忆技巧。',
#  '在ukulele的表演技巧中，有哪些有效的音阶记忆方法？',
#  '请描述一下第一种有效的ukulele音阶记忆方法是什么？',
#  '第二种有效的ukulele音阶记忆方法是什么？',
#  '请解释一下一二弦的纯四度关系在ukulele表演中的作用。',
#  '你能提供一些关于二三弦的三度关系的记忆口诀吗？',
#  '在ukulele表演中，为什么四弦与一弦之间的两个音是一样的？',
#  '如何利用ukulele四弦与其他琴弦相同的音来发挥其独特特色？',
#  '在整个指板上进行上下移动时，每移动一次会变到另外一个调。你能解释一下如何判断移动到哪一个调？',
#  '为什么ukulele上每一个品格只对应一个音名，而这个音名不能随意移动？',
#  '你能提供一些关于ukulele的表演技巧的实际应用案例吗？']

# %% [markdown]
# ### Eval Generation
#
# Now, lets generate questions on a completely different set of documents, in order to create our eval dataset.

# %%
from llama_index.llms import OpenAI
from llama_index.prompts import PromptTemplate


vary_question_tmpl = """\
你是一位音乐理论教材编辑。给定一个关于音乐家的问题，你的目标是生成多达 {num_vary} 个问题变体，涉及多个音乐理论教材。

这可能包括比较/对比不同音乐理论教材，用另一个教材替换当前的教材，或生成只能通过多个教材回答的问题（发挥创意！）

你被提供了一组有效的音乐理论教材。请仅生成可以在该组教材中回答的问题变体。

For example:
Base Question:音乐家在其创作中如何运用和声学？
Valid 10Qs:[《和声基础》, 《音乐创作指南》, 《现代和声技巧》]
Question Variations:
在《音乐创作指南》中，音乐家是如何运用和声学的？
请比较/对比《和声基础》和《现代和声技巧》中音乐家如何运用和声学，并解释其差异。
音乐家在哪本教材中描述了其对和声学的理解？

现在让我们试试吧！

Base Question: {base_question}
Valid 10Qs: {valid_10qs}
Question Variations:
"""

# %%
def gen_question_variations(base_questions, num_vary=3):
    """Generate question variations."""

    VALID_10Q_STR = "[About ukulele Performance Techniques]"

    llm = OpenAI(model="gpt-4")
    prompt_tmpl = PromptTemplate(vary_question_tmpl)

    new_questions = []
    for idx, question in enumerate(base_questions):
        new_questions.append(question)
        response = llm.complete(
            prompt_tmpl.format(
                num_vary=num_vary,
                base_question=question,
                valid_10qs=VALID_10Q_STR,
            )
        )
        # parse into newlines
        raw_lines = str(response).split("\n")
        cur_new_questions = [l for l in raw_lines if l != ""]
        print(f"[{idx}] Original Question: {question}")
        print(f"[{idx}] Generated Question Variations: {cur_new_questions}")
        new_questions.extend(cur_new_questions)

    return new_questions


def save_questions(questions, path):
    with open(path, "w") as f:
        for question in questions:
            f.write(question + "\n")


def load_questions(path):
    questions = []
    with open(path, "r") as f:
        for line in f:
            questions.append(line.strip())
    return questions

# %%
new_questions = gen_question_variations(questions)
# Out:
# [0] Original Question: 在ukulele的调弦中，第一弦到第四弦的字母分别是什么？
# [0] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，第一弦到第四弦的字母分别是什么？', '2. 请解释在《About ukulele Performance Techniques》中，ukulele的调弦是如何进行的，特别是第一弦到第四弦的字母是什么？', '3. 在《About ukulele Performance Techniques》中，ukulele的第一弦到第四弦的字母分别是什么，以及它们在音乐中的作用是什么？']
# [1] Original Question: 将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？
# [1] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？', '2. 《About ukulele Performance Techniques》中有没有详细解释如何将ukulele调弦变成C调的简谱？', '3. 你能从《About ukulele Performance Techniques》中找到将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字吗？']
# [2] Original Question: 根据全音和半音的关系，如何在指板上填满C调的音阶？
# [2] Generated Question Variations: ['1. 在《尤克里里演奏技巧》中，如何根据全音和半音的关系在指板上填满C调的音阶？', '2. 《尤克里里演奏技巧》是如何解释在指板上填满C调音阶的全音和半音关系的？', '3. 你能否根据《尤克里里演奏技巧》中的指导，解释如何在指板上填满C调的音阶？']
# [3] Original Question: 降D调的指板图相当于将C调的音阶整体往下移了几格？
# [3] Generated Question Variations: ['1. 在《尤克里里演奏技巧》中，降D调的指板图相当于将C调的音阶整体往下移了几格？', '2. 请解释在《尤克里里演奏技巧》中，为什么降D调的指板图相当于将C调的音阶整体往下移了几格？', '3. 在《尤克里里演奏技巧》中，降D调和C调的指板图有何相似之处和不同之处？']
# [4] Original Question: 在降D调的指板图中，do在原来的位置上是哪根弦的空弦？
# [4] Generated Question Variations: ['在《关于尤克里里演奏技巧》的降D调指板图中，do在原来的位置上是哪根弦的空弦？', '请在《关于尤克里里演奏技巧》中找出降D调的指板图，并确定do在原来的位置上是哪根弦的空弦？', '在《关于尤克里里演奏技巧》中，降D调的指板图是如何表示do在原来的位置上是哪根弦的空弦的？']
# [5] Original Question: 在降D调的指板图中，do向下移一个格后，变成了哪根弦的一品？
# [5] Generated Question Variations: ['在《尤克里里演奏技巧》中，当do在降D调的指板图中向下移动一个格后，它变成了哪根弦的一品？', '在《尤克里里演奏技巧》中，do在降D调的指板图中向下移动一个格后，它变成了哪个音？', '如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，这将如何影响弦的音色？']
# [6] Original Question: 在降D调的指板图中，do向下移一个格后，它的音名可以是哪两个？
# [6] Generated Question Variations: ['在《尤克里里演奏技巧》中，当do在降D调的指板图中向下移动一个格后，它的音名可以是哪两个？', '如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，它的音名可能是什么？', '在《尤克里里演奏技巧》中，do在降D调的指板图中向下移动一个格后，可能的音名是什么？']
# [7] Original Question: 方法一中提到的指型记忆适用于哪些琴弦？
# [7] Generated Question Variations: ['1. 在《关于尤克里里演奏技巧》中，方法一中提到的指型记忆适用于哪些琴弦？', '2. 《关于尤克里里演奏技巧》中是否有详细解释方法一中提到的指型记忆适用于哪些琴弦？', '3. 你能在《关于尤克里里演奏技巧》中找到关于方法一中提到的指型记忆适用于哪些琴弦的信息吗？']
# [8] Original Question: 在方法一中，列出了哪些琴弦的音阶？
# [8] Generated Question Variations: ['1. 在《关于尤克里里演奏技巧》中，列出了哪些琴弦的音阶？', '2. 《关于尤克里里演奏技巧》中的琴弦音阶与其他教材有何不同？', '3. 你能否根据《关于尤克里里演奏技巧》中的描述，解释琴弦音阶的排列方式？']
# [9] Original Question: 请描述一下方法一中的指型记忆技巧。
# [9] Generated Question Variations: ['1. 在《关于尤克里里演奏技巧》一书中，方法一是如何描述指型记忆技巧的？', '2. 请比较《关于尤克里里演奏技巧》中方法一和方法二的指型记忆技巧，并解释其差异。', '3. 在《关于尤克里里演奏技巧》一书中，哪种方法最有效地描述了指型记忆技巧？']
# [10] Original Question: 在ukulele的表演技巧中，有哪些有效的音阶记忆方法？
# [10] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，有哪些有效的音阶记忆方法？', '2. 《About ukulele Performance Techniques》是否提供了有效的音阶记忆方法，以提高ukulele的表演技巧？', '3. 你能否从《About ukulele Performance Techniques》中找到任何关于音阶记忆方法的信息，以提高ukulele的表演技巧？']
# [11] Original Question: 请描述一下第一种有效的ukulele音阶记忆方法是什么？
# [11] Generated Question Variations: ['在《About ukulele Performance Techniques》中，第一种有效的ukulele音阶记忆方法是什么？', '《About ukulele Performance Techniques》是否提供了一种有效的ukulele音阶记忆方法？', '在《About ukulele Performance Techniques》中，如何描述第一种有效的ukulele音阶记忆方法？']
# [12] Original Question: 第二种有效的ukulele音阶记忆方法是什么？
# [12] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，第二种有效的ukulele音阶记忆方法是什么？', '2. 《About ukulele Performance Techniques》是否提供了第二种有效的ukulele音阶记忆方法？', '3. 你能从《About ukulele Performance Techniques》中找到哪些有效的ukulele音阶记忆方法？']
# [13] Original Question: 请解释一下一二弦的纯四度关系在ukulele表演中的作用。
# [13] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，一二弦的纯四度关系在ukulele表演中有什么作用？', '2. 《About ukulele Performance Techniques》如何解释一二弦的纯四度关系在ukulele表演中的作用？', '3. 你能从《About ukulele Performance Techniques》中找到关于一二弦的纯四度关系在ukulele表演中的作用的信息吗？']
# [14] Original Question: 你能提供一些关于二三弦的三度关系的记忆口诀吗？
# [14] Generated Question Variations: ['在《关于尤克里里演奏技巧》中，有没有提供关于二三弦的三度关系的记忆口诀？', '《关于尤克里里演奏技巧》是如何解释二三弦的三度关系的？', '你能从《关于尤克里里演奏技巧》中找到关于二三弦的三度关系的记忆口诀吗？']
# [15] Original Question: 在ukulele表演中，为什么四弦与一弦之间的两个音是一样的？
# [15] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，为什么四弦与一弦之间的两个音是一样的？', '2. 《About ukulele Performance Techniques》是否解释了为什么ukulele表演中四弦与一弦之间的两个音是一样的？', '3. 你能从《About ukulele Performance Techniques》中找出关于ukulele四弦与一弦之间音相同的理论依据吗？']
# [16] Original Question: 如何利用ukulele四弦与其他琴弦相同的音来发挥其独特特色？
# [16] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，如何利用ukulele四弦与其他琴弦相同的音来发挥其独特特色？', '2. 《About ukulele Performance Techniques》中是否有详细介绍如何利用ukulele四弦与其他琴弦相同的音来发挥其独特特色？', '3. 请在《About ukulele Performance Techniques》中找出一种利用ukulele四弦与其他琴弦相同的音来发挥其独特特色的方法。']
# [17] Original Question: 在整个指板上进行上下移动时，每移动一次会变到另外一个调。你能解释一下如何判断移动到哪一个调？
# [17] Generated Question Variations: ['1. 在《尤克里里演奏技巧》中，如何解释在整个指板上进行上下移动时，每移动一次会变到另外一个调？', '2. 在《尤克里里演奏技巧》中，有哪些技巧可以帮助我们判断在整个指板上进行上下移动时，每移动一次会变到哪一个调？', '3. 《尤克里里演奏技巧》中是否提供了关于在整个指板上进行上下移动时，每移动一次会变到另外一个调的实例或练习？']
# [18] Original Question: 为什么ukulele上每一个品格只对应一个音名，而这个音名不能随意移动？
# [18] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，为什么每一个品格只对应一个音名，而这个音名不能随意移动？', '2. 《About ukulele Performance Techniques》是如何解释ukulele上每一个品格只对应一个音名，而这个音名不能随意移动的？', '3. 你能从《About ukulele Performance Techniques》中找到关于ukulele上每一个品格只对应一个音名，而这个音名不能随意移动的解释吗？']
# [19] Original Question: 你能提供一些关于ukulele的表演技巧的实际应用案例吗？
# [19] Generated Question Variations: ['1. 在《About ukulele Performance Techniques》中，你能找到哪些关于ukulele的表演技巧的实际应用案例？', '2. 《About ukulele Performance Techniques》中有哪些ukulele的表演技巧是特别值得学习的？', '3. 你能从《About ukulele Performance Techniques》中找到哪些ukulele的表演技巧，并解释它们如何在实际表演中应用？']

# %%
len(new_questions)
# Out:
# 80

# %%
train_questions, eval_questions = new_questions[:40], new_questions[40:]
print(len(train_questions))
# Out:
# 40

# %%
save_questions(train_questions, "train_questions_10q.txt")
save_questions(eval_questions, "eval_questions_10q.txt")

# %%
train_questions = load_questions("train_questions_10q.txt")
eval_questions = load_questions("eval_questions_10q.txt")

# %%
import os
from google.colab.output import eval_js
from google.colab import drive
# %cd /content/
drive.mount('/content/drive')
os.environ['colab_url'] = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")
# Out:
# /content
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 初始化检查文件夹
# !test -d /content/drive/MyDrive/react/train_ukulele_data || mkdir /content/drive/MyDrive/react/train_ukulele_data -p

# %%
# 同至网盘上
# !cp -r /content/storage /content/drive/MyDrive/react/train_ukulele_data/storage_`date +%Y-%m-%d_%H:%M:%S`
# !cp -r /content/eval_questions_10q.txt /content/drive/MyDrive/react/train_ukulele_data/eval_questions_10q_`date +%Y-%m-%d_%H:%M:%S`.txt

# !cp -r /content/train_questions_10q.txt /content/drive/MyDrive/react/train_ukulele_data/train_questions_10q_`date +%Y-%m-%d_%H:%M:%S`.txt

# !cp -r /content/两种有效的ukulele音阶记忆法.md /content/drive/MyDrive/react/train_ukulele_data/两种有效的ukulele音阶记忆法_`date +%Y-%m-%d_%H:%M:%S`.md

# %% [markdown]
# ## GPT-4 to Collect Training Data
#
# Here, we use GPT-4 and the `OpenAIFineTuningHandler` to collect data that we want to train on.

# %%
from llama_index import ServiceContext
from llama_index.llms import OpenAI
from llama_index.callbacks import OpenAIFineTuningHandler
from llama_index.callbacks import CallbackManager
from llama_index.agent import ReActAgent

finetuning_handler = OpenAIFineTuningHandler()
callback_manager = CallbackManager([finetuning_handler])

gpt_4_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-4", temperature=0.3),
    context_window=2048,  # limit the context window artifically to test refine process
    callback_manager=callback_manager,
)

# %%
llm = OpenAI(model="gpt-4-0613")
gpt4_agent = ReActAgent.from_tools(
    query_engine_tools,
    llm=llm,
    callback_manager=callback_manager,
    verbose=True,
)

# %%
for idx, question in enumerate(train_questions):
    print(f"[{idx}] Question: {question}")
    response = gpt4_agent.query(question)
    print(f"[{idx}] Agent Response: {str(response)}")
# Out:
# [0] Question: 在ukulele的调弦中，第一弦到第四弦的字母分别是什么？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': 'ukulele tuning'}
# Observation: The ukulele is typically tuned to the notes A, E, C, and G, which correspond to the strings from highest to lowest.
# Thought: I can answer without using any more tools.
# Response: ukulele的第一弦到第四弦的字母分别是A，E，C和G。
# [0] Agent Response: ukulele的第一弦到第四弦的字母分别是A，E，C和G。
# [1] Question: 1. 在《About ukulele Performance Techniques》中，第一弦到第四弦的字母分别是什么？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': 'About ukulele Performance Techniques 第一弦到第四弦的字母'}
# Observation: The letters for the first to fourth strings of the ukulele are A, E, C, and G, respectively.
# Thought: I can answer without using any more tools.
# Response: 在《About ukulele Performance Techniques》中，第一弦到第四弦的字母分别是A，E，C和G。
# [1] Agent Response: 在《About ukulele Performance Techniques》中，第一弦到第四弦的字母分别是A，E，C和G。
# [2] Question: 2. 请解释在《About ukulele Performance Techniques》中，ukulele的调弦是如何进行的，特别是第一弦到第四弦的字母是什么？
# Thought: 我需要使用工具来帮助我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': 'About ukulele Performance Techniques tuning'}
# Observation: There is no specific information about ukulele performance techniques or tuning in the given context.
# Thought: 我无法使用提供的工具回答这个问题。
# Response: 对不起，我无法回答您的问题。
# [2] Agent Response: 对不起，我无法回答您的问题。
# [3] Question: 3. 在《About ukulele Performance Techniques》中，ukulele的第一弦到第四弦的字母分别是什么，以及它们在音乐中的作用是什么？
# Thought: 我需要使用工具来帮助我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': 'ukulele的第一弦到第四弦的字母以及它们在音乐中的作用'}
# Observation: The letters for the first to fourth strings of a ukulele are A, E, C, and G, respectively. In music, these strings correspond to different notes and are used to play melodies, chords, and harmonies on the ukulele.
# Thought: 我可以不使用任何工具来回答这个问题。
# Response: ukulele的第一弦到第四弦的字母分别是A，E，C和G。在音乐中，这些弦对应不同的音符，用于在ukulele上演奏旋律，和弦和和声。
# [3] Agent Response: ukulele的第一弦到第四弦的字母分别是A，E，C和G。在音乐中，这些弦对应不同的音符，用于在ukulele上演奏旋律，和弦和和声。
# [4] Question: 将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？
# Thought: 我需要使用工具来帮我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': 'ukulele C调弦'}
# Observation: ukulele C调弦是指将ukulele的四根琴弦调至C调。在C调中，ukulele的四根琴弦分别对应的音符是A、E、C、G。将这四个音符变成C调的简谱后，分别是6、3、1、5。调弦到C调后，可以按照全音和半音的关系，在指板上填满C调的音阶。
# Thought: 我可以不使用任何工具来回答这个问题。
# Response: ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是6、3、1、5。
# [4] Agent Response: ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是6、3、1、5。
# [5] Question: 1. 在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是什么？'}
# Observation: 在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是6、3、1、5。
# Thought: I can answer without using any more tools.
# Response: 在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是6、3、1、5。
# [5] Agent Response: 在《About ukulele Performance Techniques》中，将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字分别是6、3、1、5。
# [6] Question: 2. 《About ukulele Performance Techniques》中有没有详细解释如何将ukulele调弦变成C调的简谱？
# Thought: 我需要使用工具来帮我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': '如何将ukulele调弦变成C调'}
# Observation: 将ukulele调弦变成C调的方法是将第一弦调成A，第二弦调成E，第三弦调成C，第四弦调成G。这样调弦后，ukulele就是C调了。
# Thought: 我可以不使用任何工具来回答这个问题。
# Response: 《About ukulele Performance Techniques》中有详细解释如何将ukulele调弦变成C调的简谱。将ukulele调弦变成C调的方法是将第一弦调成A，第二弦调成E，第三弦调成C，第四弦调成G。这样调弦后，ukulele就是C调了。
# [6] Agent Response: 《About ukulele Performance Techniques》中有详细解释如何将ukulele调弦变成C调的简谱。将ukulele调弦变成C调的方法是将第一弦调成A，第二弦调成E，第三弦调成C，第四弦调成G。这样调弦后，ukulele就是C调了。
# [7] Question: 3. 你能从《About ukulele Performance Techniques》中找到将ukulele调弦变成C调的简谱后，第一弦到第四弦的数字吗？
# Thought: 我需要使用music_theory_query工具来查询《About ukulele Performance Techniques》中关于ukulele调弦变成C调的相关信息。
# Action: music_theory_query
# Action Input: {'input': 'ukulele tuning to C key in About ukulele Performance Techniques'}
# Observation: To tune a ukulele to the C key, you need to adjust the strings to the following notes: A, E, C, and G. Once you have tuned the ukulele to C key, you can use various techniques to play in different keys. One method is to memorize the finger positions for each note on the fretboard. Another method is to memorize the intervals between the strings and use that knowledge to play in different keys.
# Thought: 根据工具的回答，ukulele调弦变成C调后，第一弦到第四弦的音符分别是G、C、E、A。在简谱中，这些音符对应的数字分别是5、1、3、6。
# Response: ukulele调弦变成C调后，第一弦到第四弦的数字分别是5、1、3、6。
# [7] Agent Response: ukulele调弦变成C调后，第一弦到第四弦的数字分别是5、1、3、6。
# [8] Question: 根据全音和半音的关系，如何在指板上填满C调的音阶？
# Thought: 我需要使用工具来帮助我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': 'C调音阶在指板上的全音和半音关系'}
# Observation: C调音阶在指板上的全音和半音关系是：mi（3）和fa（4）是半音的关系，si（7）和do（i）是半音的关系，其他的音都是全音关系。
# Thought: I can answer without using any more tools.
# Response: 在指板上填满C调的音阶，你需要遵循以下的全音和半音关系：从do到re，从re到mi，从fa到sol，从sol到la，从la到si都是全音的距离，也就是两个品格的距离。而从mi到fa和从si到高音do都是半音的距离，也就是一个品格的距离。这样，你就可以在指板上填满C调的音阶了。
# [8] Agent Response: 在指板上填满C调的音阶，你需要遵循以下的全音和半音关系：从do到re，从re到mi，从fa到sol，从sol到la，从la到si都是全音的距离，也就是两个品格的距离。而从mi到fa和从si到高音do都是半音的距离，也就是一个品格的距离。这样，你就可以在指板上填满C调的音阶了。
# [9] Question: 1. 在《尤克里里演奏技巧》中，如何根据全音和半音的关系在指板上填满C调的音阶？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '如何根据全音和半音的关系在指板上填满C调的音阶'}
# Observation: 通过了解全音和半音的关系，可以在指板上填满C调的音阶。在C调中，mi（3）和fa（4）之间是半音的关系，si（7）和do（i）之间也是半音的关系，其他音都是全音关系。因此，可以根据这个关系，在指板上逐步填满C调的音阶。
# Thought: I can answer without using any more tools.
# Response: 在尤克里里的指板上填满C调的音阶，需要理解全音和半音的关系。在C调中，mi（3）和fa（4）之间，以及si（7）和do（1）之间是半音的关系，其他音之间都是全音的关系。因此，从C开始，你可以按照全音-全音-半音-全音-全音-全音-半音的顺序在指板上找到C调的音阶。
# [9] Agent Response: 在尤克里里的指板上填满C调的音阶，需要理解全音和半音的关系。在C调中，mi（3）和fa（4）之间，以及si（7）和do（1）之间是半音的关系，其他音之间都是全音的关系。因此，从C开始，你可以按照全音-全音-半音-全音-全音-全音-半音的顺序在指板上找到C调的音阶。
# [10] Question: 2. 《尤克里里演奏技巧》是如何解释在指板上填满C调音阶的全音和半音关系的？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '尤克里里演奏技巧 C调音阶全音半音关系'}
# Observation: 尤克里里演奏中，C调音阶的全音和半音关系是基于指板上的位置来确定的。根据给定的信息，我们可以使用两种记忆方法来应用于C调音阶。第一种方法是指型记忆，其中我们需要记住六个指型，包括从低音1到高音1的弹法。通过在指型上进行上下移动，我们可以在不同的调上演奏。第二种方法是音程记忆，其中我们需要记住三种音程关系：一二弦的纯四度关系，二三弦的三度关系，以及三四弦的五度关系。通过记住这些音程关系，我们可以在弹奏任何一个琴弦时，知道隔壁琴弦的音。这些方法可以帮助我们在尤克里里演奏中应用C调音阶的全音和半音关系。
# Thought: I can answer without using any more tools.
# Response: 在《尤克里里演奏技巧》中，C调音阶的全音和半音关系是基于指板上的位置来确定的。有两种记忆方法可以应用于C调音阶。第一种是指型记忆，需要记住六个指型，包括从低音1到高音1的弹法。通过在指型上进行上下移动，可以在不同的调上演奏。第二种是音程记忆，需要记住三种音程关系：一二弦的纯四度关系，二三弦的三度关系，以及三四弦的五度关系。通过记住这些音程关系，可以在弹奏任何一个琴弦时，知道隔壁琴弦的音。这些方法可以帮助在尤克里里演奏中应用C调音阶的全音和半音关系。
# [10] Agent Response: 在《尤克里里演奏技巧》中，C调音阶的全音和半音关系是基于指板上的位置来确定的。有两种记忆方法可以应用于C调音阶。第一种是指型记忆，需要记住六个指型，包括从低音1到高音1的弹法。通过在指型上进行上下移动，可以在不同的调上演奏。第二种是音程记忆，需要记住三种音程关系：一二弦的纯四度关系，二三弦的三度关系，以及三四弦的五度关系。通过记住这些音程关系，可以在弹奏任何一个琴弦时，知道隔壁琴弦的音。这些方法可以帮助在尤克里里演奏中应用C调音阶的全音和半音关系。
# [11] Question: 3. 你能否根据《尤克里里演奏技巧》中的指导，解释如何在指板上填满C调的音阶？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '如何在尤克里里的指板上填满C调的音阶'}
# Observation: 可以通过将C调的音阶填满在尤克里里的指板上来实现。根据全音与半音的关系，可以将C调的音阶填满在指板上。其中，mi（3）和fa（4）是半音的关系，si（7）和do（i）是半音的关系，其他的音都是全音关系。通过记住C调的指型，即从低音1到高音1的弹法，可以在指板上任意变调。另外，还可以通过记忆音程关系来填满C调的音阶，包括一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系。通过这些方法，可以在尤克里里的指板上填满C调的音阶。
# Thought: I can answer without using any more tools.
# Response: 在尤克里里的指板上填满C调的音阶，可以通过以下步骤实现：
#
# 1. 首先，需要理解全音与半音的关系。在C调中，mi（3）和fa（4）之间，以及si（7）和do（1）之间是半音的关系，其他的音都是全音关系。
#
# 2. 其次，记住C调的指型，即从低音1到高音1的弹法，可以在指板上任意变调。
#
# 3. 最后，记忆音程关系也是非常重要的。在尤克里里上，一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系，这些都可以帮助你在指板上填满C调的音阶。
#
# 通过以上的方法，你可以在尤克里里的指板上填满C调的音阶。
# [11] Agent Response: 在尤克里里的指板上填满C调的音阶，可以通过以下步骤实现：
#
# 1. 首先，需要理解全音与半音的关系。在C调中，mi（3）和fa（4）之间，以及si（7）和do（1）之间是半音的关系，其他的音都是全音关系。
#
# 2. 其次，记住C调的指型，即从低音1到高音1的弹法，可以在指板上任意变调。
#
# 3. 最后，记忆音程关系也是非常重要的。在尤克里里上，一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系，这些都可以帮助你在指板上填满C调的音阶。
#
# 通过以上的方法，你可以在尤克里里的指板上填满C调的音阶。
# [12] Question: 降D调的指板图相当于将C调的音阶整体往下移了几格？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调和C调的关系'}
# Observation: 降D调和C调的关系是，降D调的指板图相当于把C调的音阶都整体往下移了一格。也就是说，降D调的do本来在第三弦的空弦，现在向下移一个格变成三弦一品，相当于钢琴上的黑键，它的音名有两个：#C或bD。所以降D调的指板图可以叫它#C指板图或bD指板图。
# Thought: I can answer without using any more tools.
# Response: 降D调的指板图相当于将C调的音阶整体往下移了一格。
# [12] Agent Response: 降D调的指板图相当于将C调的音阶整体往下移了一格。
# [13] Question: 1. 在《尤克里里演奏技巧》中，降D调的指板图相当于将C调的音阶整体往下移了几格？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调的指板图相对于C调的移动'}
# Observation: 降D调的指板图相对于C调的移动是将C调的音阶整体往下移了一格。也就是说，降D调的指板图中，原本在C调的第三弦空弦的do音，现在向下移一个格，变成了降D调的第三弦一品，相当于钢琴上的黑键。这个音在降D调中有两个音名，可以称为#C或bD。所以降D调的指板图可以称为#C指板图或bD指板图。
# Thought: I can answer without using any more tools.
# Response: 降D调的指板图相对于C调的音阶整体往下移了一格。
# [13] Agent Response: 降D调的指板图相对于C调的音阶整体往下移了一格。
# [14] Question: 2. 请解释在《尤克里里演奏技巧》中，为什么降D调的指板图相当于将C调的音阶整体往下移了几格？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调的指板图相当于将C调的音阶整体往下移了几格'}
# Observation: 降D调的指板图相当于将C调的音阶整体往下移了一格。
# Thought: I can answer without using any more tools.
# Response: 降D调的指板图相当于将C调的音阶整体往下移了一格。这是因为在音乐理论中，降D调是C调的下一个半音，所以在尤克里里的指板上，降D调的位置就是C调的下一格。
# [14] Agent Response: 降D调的指板图相当于将C调的音阶整体往下移了一格。这是因为在音乐理论中，降D调是C调的下一个半音，所以在尤克里里的指板上，降D调的位置就是C调的下一格。
# [15] Question: 3. 在《尤克里里演奏技巧》中，降D调和C调的指板图有何相似之处和不同之处？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调和C调在尤克里里上的指板图相似之处和不同之处'}
# Observation: 降D调和C调在尤克里里上的指板图相似之处是它们都是基于相同的音阶构建的，只是位置不同。它们都使用相同的指型记忆方法和音程记忆方法来确定音阶的位置。不同之处是降D调的指板图相对于C调的指板图整体向下移动了一格，因此降D调的指板图上的音符位置都相对于C调的指板图向下移动了一格。此外，降D调的指板图上的do（1）位于第三弦的一品上，而C调的指板图上的do（1）位于第三弦的空弦上。
# Thought: I can answer without using any more tools.
# Response: 降D调和C调在尤克里里上的指板图的相似之处是它们都是基于相同的音阶构建的，只是位置不同。它们都使用相同的指型记忆方法和音程记忆方法来确定音阶的位置。不同之处在于，降D调的指板图相对于C调的指板图整体向下移动了一格，因此降D调的指板图上的音符位置都相对于C调的指板图向下移动了一格。此外，降D调的指板图上的do（1）位于第三弦的一品上，而C调的指板图上的do（1）位于第三弦的空弦上。
# [15] Agent Response: 降D调和C调在尤克里里上的指板图的相似之处是它们都是基于相同的音阶构建的，只是位置不同。它们都使用相同的指型记忆方法和音程记忆方法来确定音阶的位置。不同之处在于，降D调的指板图相对于C调的指板图整体向下移动了一格，因此降D调的指板图上的音符位置都相对于C调的指板图向下移动了一格。此外，降D调的指板图上的do（1）位于第三弦的一品上，而C调的指板图上的do（1）位于第三弦的空弦上。
# [16] Question: 在降D调的指板图中，do在原来的位置上是哪根弦的空弦？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调的指板图'}
# Observation: #C指板图或bD指板图
# Thought: The tool has provided a response, but it seems to be a bit unclear. The response indicates a C# or Db fretboard diagram, which is not exactly what we're looking for. However, we can infer that in a Db tuning, the strings would be tuned down by a half step from standard tuning. In standard tuning, the open strings from low to high are E, A, D, G, B, E. If we tune each string down by a half step, we get Db, Ab, Db, Gb, B, Eb. Therefore, the 'do' note in its original position would be the open string of the third string in a Db tuning.
#
# Thought: I can answer without using any more tools.
# Response: 在降D调的指板图中，'do'在原来的位置上是第三根弦的空弦。
# [16] Agent Response: 在降D调的指板图中，'do'在原来的位置上是第三根弦的空弦。
# [17] Question: 在《关于尤克里里演奏技巧》的降D调指板图中，do在原来的位置上是哪根弦的空弦？
# Thought: I need to use the music_theory_query tool to find out the position of "do" in the D-tuning fretboard diagram of the ukulele.
# Action: music_theory_query
# Action Input: {'input': '在《关于尤克里里演奏技巧》的降D调指板图中，do在原来的位置上是哪根弦的空弦？'}
# Observation: 在《关于尤克里里演奏技巧》的降D调指板图中，do在原来的位置上是第三弦的空弦。
# Thought: I can answer without using any more tools.
# Response: 在《关于尤克里里演奏技巧》的降D调指板图中，"do"在原来的位置上是第三弦的空弦。
# [17] Agent Response: 在《关于尤克里里演奏技巧》的降D调指板图中，"do"在原来的位置上是第三弦的空弦。
# [18] Question: 请在《关于尤克里里演奏技巧》中找出降D调的指板图，并确定do在原来的位置上是哪根弦的空弦？
# Thought: I need to use the music_theory_query tool to find the information about the fretboard diagram of D tuning in ukulele and determine which string is the open string for 'do' in the original position.
# Action: music_theory_query
# Action Input: {'input': '降D调尤克里里指板图'}
# Observation: #C指板图或bD指板图是降D调尤克里里的指板图。
# Thought: Now I know the fretboard diagram for D tuning in ukulele is the C fretboard diagram or bD fretboard diagram. I need to find out which string is the open string for 'do' in the original position.
# Action: music_theory_query
# Action Input: {'input': '尤克里里do空弦'}
# Observation: 尤克里里的do空弦是指将第三弦按在一品上弹奏。
# Thought: I can answer without using any more tools.
# Response: 降D调的尤克里里指板图是C指板图或bD指板图。在原来的位置上，'do'是第三弦的一品。
# [18] Agent Response: 降D调的尤克里里指板图是C指板图或bD指板图。在原来的位置上，'do'是第三弦的一品。
# [19] Question: 在《关于尤克里里演奏技巧》中，降D调的指板图是如何表示do在原来的位置上是哪根弦的空弦的？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调尤克里里指板图'}
# Observation: #C指板图或bD指板图是降D调尤克里里的指板图。
# Thought: I can answer without using any more tools.
# Response: 在降D调的尤克里里指板图中，do（C或bD）通常表示在第四根弦的空弦上。
# [19] Agent Response: 在降D调的尤克里里指板图中，do（C或bD）通常表示在第四根弦的空弦上。
# [20] Question: 在降D调的指板图中，do向下移一个格后，变成了哪根弦的一品？
# Thought: I need to use the music theory tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调的指板图'}
# Observation: #C指板图或bD指板图
# Thought: The tool has provided the information that the tuning is C or bD. Now, I need to consider the question again: if 'do' moves down one fret in this tuning, which string does it become? In standard tuning, 'do' is C. If we move down one fret, it becomes B or si. However, in the tuning provided, we need to consider the specific strings and their tuning.
# Action: music_theory_query
# Action Input: {'input': '降D调的各弦调音'}
# Observation: 降D调的各弦调音是#C、F、A、D。
# Thought: Now I know the tuning of each string in bD tuning is #C, F, A, D. If 'do' (#C) moves down one fret, it becomes B or 'si'. However, in this tuning, the first fret of the #C string becomes B, which is not the open note of any string in this tuning. Therefore, 'do' moving down one fret does not correspond to the open note of any string in bD tuning.
# Thought: I can answer without using any more tools.
# Response: 'do'向下移一个格后，变成了B音，但在降D调的各弦调音中，并没有对应的一品开弦。
# [20] Agent Response: 'do'向下移一个格后，变成了B音，但在降D调的各弦调音中，并没有对应的一品开弦。
# [21] Question: 在《尤克里里演奏技巧》中，当do在降D调的指板图中向下移动一个格后，它变成了哪根弦的一品？
# Thought: 我需要使用工具来帮我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': '在降D调的尤克里里指板图中，do向下移动一个格后的位置'}
# Observation: 在降D调的尤克里里指板图中，do向下移动一个格后的位置是三弦一品。
# Thought: I can answer without using any more tools.
# Response: 当do在降D调的尤克里里指板图中向下移动一个格后，它变成了三弦的一品。
# [21] Agent Response: 当do在降D调的尤克里里指板图中向下移动一个格后，它变成了三弦的一品。
# [22] Question: 在《尤克里里演奏技巧》中，do在降D调的指板图中向下移动一个格后，它变成了哪个音？
# Thought: 我需要使用工具来帮我回答这个问题。
# Action: music_theory_query
# Action Input: {'input': '在降D调中，do向下移动一个格后的音'}
# Observation: 在降D调中，do向下移动一个格后的音是#C或bD。
# Thought: I can answer without using any more tools.
# Response: 在降D调中，do向下移动一个格后的音是#C或bD。
# [22] Agent Response: 在降D调中，do向下移动一个格后的音是#C或bD。
# [23] Question: 如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，这将如何影响弦的音色？
# Thought: I need to use the music_theory_query tool to understand how moving the 'do' note down one fret in a D minor fretboard diagram would affect the tone of the strings in ukulele performance techniques.
# Action: music_theory_query
# Action Input: {'input': '在降D调的指板图中，do向下移动一个格的影响'}
# Observation: 在降D调的指板图中，将do向下移动一个格会导致它从第三弦的空弦变为三弦一品。这个移动会改变do的音名，它可以被称为#C或bD。
# Thought: Based on the tool's response, moving the 'do' note down one fret in a D minor fretboard diagram changes it from an open string on the third string to the first fret of the third string. This changes the note's name, which can be referred to as #C or bD. Now, I need to understand how this change would affect the tone of the strings in ukulele performance techniques.
# Action: music_theory_query
# Action Input: {'input': '尤克里里演奏技巧中，#C或bD的音色影响'}
# Observation: The playing technique of #C or bD in ukulele can have an impact on the tone or sound quality.
# Thought: I can answer without using any more tools.
# Response: 在降D调的指板图中，将'do'向下移动一个格会改变它的音名，可以被称为#C或bD。这个改变会影响尤克里里的演奏技巧，因为#C或bD的演奏方式会对音色或声音质量产生影响。具体的影响取决于演奏者的技巧和演奏风格。
# [23] Agent Response: 在降D调的指板图中，将'do'向下移动一个格会改变它的音名，可以被称为#C或bD。这个改变会影响尤克里里的演奏技巧，因为#C或bD的演奏方式会对音色或声音质量产生影响。具体的影响取决于演奏者的技巧和演奏风格。
# [24] Question: 在降D调的指板图中，do向下移一个格后，它的音名可以是哪两个？
# Thought: 降D调的指板图中，do向下移一个格后，它的音名可能会改变。我需要使用乐理检索工具来找到这个问题的答案。
# Action: music_theory_query
# Action Input: {'input': '降D调 do向下移一个格'}
# Observation: do向下移一个格变成三弦一品，相当于钢琴上的黑键，它的音名有两个：#C或bD。
# Thought: I can answer without using any more tools.
# Response: do向下移一个格后，它的音名可以是#C或bD。
# [24] Agent Response: do向下移一个格后，它的音名可以是#C或bD。
# [25] Question: 在《尤克里里演奏技巧》中，当do在降D调的指板图中向下移动一个格后，它的音名可以是哪两个？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '在降D调的指板图中，do向下移动一个格后的音名'}
# Observation: #C或bD
# Thought: I can answer without using any more tools.
# Response: 当do在降D调的指板图中向下移动一个格后，它的音名可以是#C或bD。
# [25] Agent Response: 当do在降D调的指板图中向下移动一个格后，它的音名可以是#C或bD。
# [26] Question: 如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，它的音名可能是什么？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '降D调 do向下移动一个格'}
# Observation: do向下移动一个格变成三弦一品，相当于钢琴上的黑键，它的音名有两个：#C或bD。
# Thought: I can answer without using any more tools.
# Response: 如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，它的音名可能是#C或bD。
# [26] Agent Response: 如果在降D调的指板图中，do向下移动一个格，那么在《尤克里里演奏技巧》中，它的音名可能是#C或bD。
# [27] Question: 在《尤克里里演奏技巧》中，do在降D调的指板图中向下移动一个格后，可能的音名是什么？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '在降D调中，do向下移动一个格后的音名'}
# Observation: 在降D调中，do向下移动一个格后的音名是#C或bD。
# Thought: I can answer without using any more tools.
# Response: 在降D调的尤克里里指板图中，do向下移动一个格后，可能的音名是#C或bD。
# [27] Agent Response: 在降D调的尤克里里指板图中，do向下移动一个格后，可能的音名是#C或bD。
# [28] Question: 方法一中提到的指型记忆适用于哪些琴弦？
# Thought: The question is asking about the applicability of fingering memory mentioned in Method One to certain strings. To answer this question, I need to understand what Method One refers to and what it entails. However, the current conversation does not provide this context. I will need to ask for more information.
# Response: Could you please provide more details about Method One and the specific context in which it was mentioned? This will help me provide a more accurate answer.
# [28] Agent Response: Could you please provide more details about Method One and the specific context in which it was mentioned? This will help me provide a more accurate answer.
# [29] Question: 1. 在《关于尤克里里演奏技巧》中，方法一中提到的指型记忆适用于哪些琴弦？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧 方法一 指型记忆'}
# Observation: 方法一是指型记忆。这种记忆方法是通过记住不同指型的方式来演奏不同的音阶。在尤克里里演奏中，有六个不同的指型，每个指型对应着不同的音阶。通过记住这些指型，可以在不同的调中演奏出相应的音阶。这种方法特别适用于使用high G琴弦的尤克里里。
# Thought: I can answer without using any more tools.
# Response: 方法一中提到的指型记忆适用于使用high G琴弦的尤克里里。
# [29] Agent Response: 方法一中提到的指型记忆适用于使用high G琴弦的尤克里里。
# [30] Question: 2. 《关于尤克里里演奏技巧》中是否有详细解释方法一中提到的指型记忆适用于哪些琴弦？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '指型记忆适用于哪些琴弦'}
# Observation: 指型记忆适用于前三条琴弦。
# Thought: I can answer without using any more tools.
# Response: 指型记忆适用于前三条琴弦。
# [30] Agent Response: 指型记忆适用于前三条琴弦。
# [31] Question: 3. 你能在《关于尤克里里演奏技巧》中找到关于方法一中提到的指型记忆适用于哪些琴弦的信息吗？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '方法一中的指型记忆适用于哪些琴弦'}
# Observation: 方法一中的指型记忆适用于前三条琴弦。
# Thought: I can answer without using any more tools.
# Response: 方法一中的指型记忆适用于前三条琴弦。
# [31] Agent Response: 方法一中的指型记忆适用于前三条琴弦。
# [32] Question: 在方法一中，列出了哪些琴弦的音阶？
# Thought: I need to use a tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '方法一'}
# Observation: 指型记忆
# Thought: The tool response is not clear enough to answer the question. I need to use the tool again with a more specific query.
# Action: music_theory_query
# Action Input: {'input': '指型记忆'}
# Observation: 指型记忆是一种记忆方法，用于记住不同音阶的指法。通过记住特定的指型，可以在不同的调上演奏相同的音阶。这种方法适用于大部分使用high G琴弦的ukulele。通过记住特定的指型，可以在不同的调上演奏相同的音阶。这种方法可以帮助演奏者在整个指板上进行上下移动，并且每次移动都会变到另外一个调。
# Thought: The tool response does not directly answer the question about which scales are listed for the strings in Method One. However, it does provide some information about the method, which involves memorizing finger positions to play the same scale in different keys. This method is applicable to most ukuleles using a high G string. The method allows the player to move up and down the fretboard, changing keys with each move.
# Action: music_theory_query
# Action Input: {'input': '方法一 琴弦 音阶'}
# Observation: 方法一是指型记忆，它是一种记忆ukulele音阶的方法。在这种方法中，我们需要记住每个音阶的指型，也就是从低音到高音的弹法。通过记住这些指型，我们可以在不同的调上进行变调。而琴弦是ukulele的弦，它们分别是第一弦、第二弦、第三弦和第四弦。所以方法一中的琴弦指的是ukulele的弦，而音阶指的是ukulele的音阶。
# Thought: The tool response still does not directly answer the question about which scales are listed for the strings in Method One. It only explains that Method One involves memorizing finger positions to play the same scale in different keys on the ukulele, and that the strings of the ukulele are referred to as the first, second, third, and fourth strings. However, it does not specify which scales are listed for these strings in Method One.
# Response: Sorry, I cannot answer your query.
# [32] Agent Response: Sorry, I cannot answer your query.
# [33] Question: 1. 在《关于尤克里里演奏技巧》中，列出了哪些琴弦的音阶？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧 琴弦 音阶'}
# Observation: 尤克里里演奏技巧涉及琴弦和音阶。根据给定的上下文信息，尤克里里有四根琴弦，分别调弦为A、E、C、G。关于音阶，文章提到了两种有效的记忆方法：指型记忆和音程记忆。指型记忆是记住每个音的指型，通过移动指型来变调。音程记忆是记住不同弦之间的音程关系，如纯四度、小三度和五度。文章还提到了尤克里里的特点，即第四弦与第二弦和第一弦之间有相同的音。这些技巧和知识可以帮助尤克里里演奏者在不同调上进行演奏。
# Thought: I can answer without using any more tools.
# Response: 在《关于尤克里里演奏技巧》中，尤克里里的四根琴弦分别调弦为A、E、C、G。关于音阶，文章提到了两种有效的记忆方法：指型记忆和音程记忆。指型记忆是记住每个音的指型，通过移动指型来变调。音程记忆是记住不同弦之间的音程关系，如纯四度、小三度和五度。文章还提到了尤克里里的特点，即第四弦与第二弦和第一弦之间有相同的音。这些技巧和知识可以帮助尤克里里演奏者在不同调上进行演奏。
# [33] Agent Response: 在《关于尤克里里演奏技巧》中，尤克里里的四根琴弦分别调弦为A、E、C、G。关于音阶，文章提到了两种有效的记忆方法：指型记忆和音程记忆。指型记忆是记住每个音的指型，通过移动指型来变调。音程记忆是记住不同弦之间的音程关系，如纯四度、小三度和五度。文章还提到了尤克里里的特点，即第四弦与第二弦和第一弦之间有相同的音。这些技巧和知识可以帮助尤克里里演奏者在不同调上进行演奏。
# [34] Question: 2. 《关于尤克里里演奏技巧》中的琴弦音阶与其他教材有何不同？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '尤克里里演奏技巧 琴弦音阶'}
# Observation: There are two effective methods for memorizing ukulele scales: the finger pattern method and the interval method. The finger pattern method involves memorizing the finger positions for each note, starting with the "do" note on the third string. By moving the finger pattern up or down the fretboard, you can play in different keys. The interval method involves memorizing the interval relationships between the strings. For example, the first and second strings have a perfect fourth interval, while the second and third strings have a major third interval. By memorizing these interval relationships, you can determine the notes on neighboring strings. Additionally, it is important to note that the fourth string is usually tuned to high G, and it shares the same notes as the second string. Similarly, the fourth string shares the same notes as the first string, with one fret in between. These methods allow you to play scales in different keys on the ukulele.
# Thought: I can answer without using any more tools.
# Response: 《关于尤克里里演奏技巧》中的琴弦音阶与其他教材的主要区别在于其记忆方法。这本教材提供了两种有效的记忆尤克里里音阶的方法：指模式法和间隔法。指模式法涉及记忆每个音符的指位，从第三弦的“do”音符开始。通过在指板上上下移动指模式，你可以在不同的调上演奏。间隔法涉及记忆弦之间的间隔关系。例如，第一弦和第二弦之间有完全四度的间隔，而第二弦和第三弦之间有大三度的间隔。通过记忆这些间隔关系，你可以确定相邻弦上的音符。此外，需要注意的是，第四弦通常调到高G，它与第二弦共享相同的音符。同样，第四弦与第一弦共享相同的音符，中间隔着一个品。这些方法允许你在尤克里里上演奏不同调的音阶。
# [34] Agent Response: 《关于尤克里里演奏技巧》中的琴弦音阶与其他教材的主要区别在于其记忆方法。这本教材提供了两种有效的记忆尤克里里音阶的方法：指模式法和间隔法。指模式法涉及记忆每个音符的指位，从第三弦的“do”音符开始。通过在指板上上下移动指模式，你可以在不同的调上演奏。间隔法涉及记忆弦之间的间隔关系。例如，第一弦和第二弦之间有完全四度的间隔，而第二弦和第三弦之间有大三度的间隔。通过记忆这些间隔关系，你可以确定相邻弦上的音符。此外，需要注意的是，第四弦通常调到高G，它与第二弦共享相同的音符。同样，第四弦与第一弦共享相同的音符，中间隔着一个品。这些方法允许你在尤克里里上演奏不同调的音阶。
# [35] Question: 3. 你能否根据《关于尤克里里演奏技巧》中的描述，解释琴弦音阶的排列方式？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧'}
# Observation: 尤克里里演奏技巧有很多种，其中包括指型记忆和音程记忆两种方法。指型记忆是通过记住不同指型的方式来演奏不同的音阶，而音程记忆则是通过记住不同音程关系的口诀来确定不同音阶的音。这些方法可以帮助演奏者在不同调上进行演奏，并且可以应用到整个指板上进行上下移动。另外，了解尤克里里的调弦和指板图也是演奏技巧的一部分。
# Thought: The tool response provides information about ukulele performance techniques, including fingering memory and interval memory methods. However, it does not directly explain the arrangement of the string scales. I need to use the tool again to get more specific information about the arrangement of the string scales.
# Action: music_theory_query
# Action Input: {'input': '尤克里里琴弦音阶排列'}
# Observation: A E C G
# Thought: I can answer without using any more tools.
# Response: 尤克里里的琴弦音阶从上到下（即从最靠近演奏者的一根弦开始）通常是A、E、C、G。
# [35] Agent Response: 尤克里里的琴弦音阶从上到下（即从最靠近演奏者的一根弦开始）通常是A、E、C、G。
# [36] Question: 请描述一下方法一中的指型记忆技巧。
# Thought: I need to use a tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '方法一中的指型记忆技巧'}
# Observation: 方法一中的指型记忆技巧是通过记住每个音阶的指型来实现的。在ukulele上，每个音阶都有一个特定的指型，即从低音到高音的弹法。通过记住这些指型，可以在不同调上自由变调。这种方法适用于大部分使用high G琴弦的ukulele。
# Thought: I can answer without using any more tools.
# Response: 方法一中的指型记忆技巧是通过记住每个音阶的指型来实现的。在ukulele上，每个音阶都有一个特定的指型，即从低音到高音的弹法。通过记住这些指型，可以在不同调上自由变调。这种方法适用于大部分使用high G琴弦的ukulele。
# [36] Agent Response: 方法一中的指型记忆技巧是通过记住每个音阶的指型来实现的。在ukulele上，每个音阶都有一个特定的指型，即从低音到高音的弹法。通过记住这些指型，可以在不同调上自由变调。这种方法适用于大部分使用high G琴弦的ukulele。
# [37] Question: 1. 在《关于尤克里里演奏技巧》一书中，方法一是如何描述指型记忆技巧的？
# Thought: I need to use the music_theory_query tool to help me answer the question.
# Action: music_theory_query
# Action Input: {'input': '《关于尤克里里演奏技巧》一书中，方法一是如何描述指型记忆技巧的'}
# Observation: In the book "关于尤克里里演奏技巧", method one describes the technique of memorizing finger patterns.
# Thought: I can answer without using any more tools.
# Response: 在《关于尤克里里演奏技巧》一书中，方法一描述了记忆指型的技巧。
# [37] Agent Response: 在《关于尤克里里演奏技巧》一书中，方法一描述了记忆指型的技巧。
# [38] Question: 2. 请比较《关于尤克里里演奏技巧》中方法一和方法二的指型记忆技巧，并解释其差异。
# Thought: I need to use the music_theory_query tool to get information about the finger memory techniques in Method 1 and Method 2 in "About Ukulele Performance Techniques".
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧 方法一 指型记忆技巧'}
# Observation: 方法一是指型记忆技巧。这种方法是通过记住不同指型的方式来演奏不同的音阶。在这种方法中，我们需要记住六个指型，包括do指型和其他五个指型。通过记住这些指型，我们可以在不同的调中运用它们。这种方法适用于大部分使用high G琴弦的尤克里里演奏者。
# Thought: Now I have the information about the finger memory techniques in Method 1. I need to use the music_theory_query tool again to get information about the finger memory techniques in Method 2.
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧 方法二 指型记忆技巧'}
# Observation: 方法二是指型记忆技巧。这种记忆方法是通过记住不同指型的方式来演奏不同的音阶。在这种方法中，我们需要记住六个指型，包括do指型和其他五个指型。通过记住这些指型，我们可以在不同的调中运用它们。这种方法可以帮助我们在演奏时快速找到正确的音。
# Thought: I can answer without using any more tools.
# Response: 方法一和方法二的指型记忆技巧都是通过记住不同的指型来演奏不同的音阶，包括do指型和其他五个指型。这些指型可以在不同的调中运用。但是，方法一主要适用于大部分使用high G琴弦的尤克里里演奏者，而方法二则可以帮助演奏者在演奏时快速找到正确的音。
# [38] Agent Response: 方法一和方法二的指型记忆技巧都是通过记住不同的指型来演奏不同的音阶，包括do指型和其他五个指型。这些指型可以在不同的调中运用。但是，方法一主要适用于大部分使用high G琴弦的尤克里里演奏者，而方法二则可以帮助演奏者在演奏时快速找到正确的音。
# [39] Question: 3. 在《关于尤克里里演奏技巧》一书中，哪种方法最有效地描述了指型记忆技巧？
# Thought: I need to use the music_theory_query tool to find information about finger memory techniques in the book "About Ukulele Performance Techniques".
# Action: music_theory_query
# Action Input: {'input': '关于尤克里里演奏技巧 指型记忆技巧'}
# Observation: 指型记忆是一种有效的尤克里里演奏技巧。通过记住不同指型的方式，可以在不同调上演奏。在尤克里里演奏中，有六个指型需要记住，包括do指型和其他五个指型。此外，还可以通过记忆音程关系来辅助演奏。音程关系包括一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系。通过记住这些指型和音程关系，可以在不同调上自由演奏。
# Thought: I can answer without using any more tools.
# Response: 《关于尤克里里演奏技巧》一书中，最有效地描述了指型记忆技巧的方法是记住不同的指型和音程关系。在尤克里里演奏中，有六个指型需要记住，包括do指型和其他五个指型。此外，还可以通过记忆音程关系来辅助演奏。音程关系包括一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系。通过记住这些指型和音程关系，可以在不同调上自由演奏。
# [39] Agent Response: 《关于尤克里里演奏技巧》一书中，最有效地描述了指型记忆技巧的方法是记住不同的指型和音程关系。在尤克里里演奏中，有六个指型需要记住，包括do指型和其他五个指型。此外，还可以通过记忆音程关系来辅助演奏。音程关系包括一二弦的纯四度关系、二三弦的三度关系和三四弦的五度关系。通过记住这些指型和音程关系，可以在不同调上自由演奏。

# %%
# save events
finetuning_handler.save_finetuning_events("finetuning_events_10q.jsonl")
# Out:
# Wrote 86 examples to finetuning_events_10q.jsonl

# %%
# !cp -r /content/finetuning_events_10q.jsonl /content/drive/MyDrive/react/train_ukulele_data/finetuning_events_10q_`date +%Y-%m-%d_%H:%M:%S`.jsonl

# %% [markdown]
# ## 未使用Create `OpenAIFinetuneEngine`
#
# We create an `OpenAIFinetuneEngine`: the finetune engine will take care of launching a finetuning job, and returning an LLM model that you can directly plugin to the rest of LlamaIndex workflows.
#
# We use the default constructor, but we can also directly pass in our finetuning_handler into this engine with the `from_finetuning_handler` class method.

# %%
finetuning_handler.save_finetuning_events("finetuning_events.jsonl")

# %%
from llama_index.finetuning import OpenAIFinetuneEngine

finetune_engine = OpenAIFinetuneEngine(
    "gpt-3.5-turbo",
    "finetuning_events.jsonl",
    # start_job_id="<start-job-id>"  # if you have an existing job, can specify id here
)

# finetune_engine = OpenAIFinetuneEngine.from_finetuning_handler(
#     finetuning_handler,
#     "gpt-3.5-turbo",
#     "tmp.jsonl"
# )

# %%
finetune_engine.finetune()
# Out:
# Num examples: 61
# First example:
# {'role': 'system', 'content': "You are an expert Q&A system that is trusted around the world.\nAlways answer the query using the provided context information, and not prior knowledge.\nSome rules to follow:\n1. Never directly reference the given context in your answer.\n2. Avoid statements like 'Based on the context, ...' or 'The context information ...' or anything along those lines."}
# {'role': 'user', 'content': 'Context information is below.\n---------------------\npage_label: 410\nfile_name: IPCC_AR6_WGII_Chapter03.pdf\n\nIt is challenging to apply this experimental approach to communities or ecosystems (see Figure \nBox\xa03.1.1).To date, most research on community or ecosystem response to climate-induced drivers has been in large-volume (>10,000 l) \nmesocosms (Riebesell and Gattuso, 2014), or at natural analogues such as CO 2 seeps, in which only one driver (ocean acidification) is \naltered (see (4) in Figure Box\xa03.1.1).Only very recently have two drivers been incorporated into climate-change manipulation studies \nexamining responses of primary producers to secondary consumers (see (5) in Figure Box\xa03.1.1a; Nagelkerken et\xa0al., 2020).Therefore, \n‘natural experiments’ from the geological past (Reddin et\xa0al., 2020) provide insights into how food webs and their constituents respond to \ncomplex change involving multiple drivers.Contemporary observations are occasionally long enough (>50\xa0years) to capture community \nresponses to complex climate change.For example, Brun et\xa0al.(2019) reported a shift in zooplankton community structure in the North \nAtlantic (1960–2014), with major biogeochemical ramifications.Conducting sufficiently long manipulation experiments to study the effect of adaptation on organisms is equally difficult (see Figure \nBox\xa03.1.1b), with much research restricted to multi-year studies of the microevolution of fast-growing (more than one division per day) \nphytoplankton species responding to single drivers (Lohbeck et\xa0al., 2012; Schaum et\xa0al., 2016).In a few experimental evolution studies \n(see (7) in Figure Box\xa03.1.1a; Brennan et\xa0al., 2017), multiple drivers have been used, but none have used communities or ecosystems (see \nFigure Box\xa03.1.1b).Nevertheless, the fossil record provides limited evidence of adaptations to less rapid (relative to present day) climate \nchange (Jackson et\xa0al., 2018).Despite the need to explore ecological or biogeochemical responses to projected future ocean conditions, \nlogistical challenges require that assessments of climate-change impacts at scales larger than mesocosms use large-scale, long-term in \nsitu observational studies (as documented in Section\xa03.4).\n\npage_label: 409\nfile_name: IPCC_AR6_WGII_Chapter03.pdf\n\n3\n409Oceans and Coastal Ecosystems and Their Services  Chapter 3\nunderlies inhibited thermal adaptation under nitrogen-limited \nconditions (low confidence) (Aranguren-Gassis et\xa0 al., 2019).When \nselection is strong due to unfavourable environmental conditions, \nmicrobial populations can encounter functional and evolutionary \ntrade-offs evidenced by reducing growth rates while increasing \ntolerance and metabolism of reactive oxygen species (Lindberg and \nCollins, 2020).Other trade-offs can be observed in offspring quality \nand number (Lindberg and Collins, 2020).These findings contribute \ntowards a mechanistic framework describing the range of evolutionary \nstrategies in response to multiple drivers (Collins et\xa0al., 2020), but other \nhazards, such as extreme events (e.g., MHWs), still need to be included \nbecause their characteristics may alter the potential for adaptation of \nspecies and populations to climate change (Gruber et\xa0al., 2021).3.3.5 Ecological Response to Multiple Drivers\nAssessing ecological responses to multiple climate-induced drivers \nrequires a combination of approaches, including laboratory- and \nfield-based experiments, field observations (e.g., natural gradients, \nclimate analogues), study of paleo-analogues and the development \nof mechanistic and empirical models (Clapham, 2019; Gissi et\xa0 al., \n2021).Experimental studies of food-web responses are often limited \nto an individual driver, although recent manipulations have used a \nmatrix of >1000-l mesocosms to explore ecological responses to both \nwarming and acidification (see Box\xa0 3.1 ...
# {'role': 'assistant', 'content': 'Several approaches are used to assess ecological responses to multiple climate-induced drivers. These include laboratory- and field-based experiments, field observations such as natural gradients and climate analogues, the study of paleo-analogues, and the development of mechanistic and empirical models. Experimental studies often focus on individual drivers, but recent manipulations have used large-volume mesocosms to explore ecological responses to both warming and acidification. Observations from time series longer than modes of natural variability are essential for revealing and attributing ecological responses to climate change. Paleorecords also provide insights into the influence of multiple drivers on marine biota. Multi-species and integrated end-to-end ecosystem models are powerful tools to explore and project outcomes to the often-interacting cumulative effects of climate change and other anthropogenic drivers. These models can integrate some aspects of the knowledge accrued from manipulation experiments, paleo- and contemporary observations, help test the relative importance of specific drivers and driver combinations, and identify synergistic or antagonistic responses.'}
# No errors found
# Num examples missing system message: 21
# Num examples missing user message: 0
#
# #### Distribution of num_messages_per_example:
# min / max: 2, 3
# mean / median: 2.6557377049180326, 3.0
# p5 / p95: 2.0, 3.0
#
# #### Distribution of num_total_tokens_per_example:
# min / max: 229, 2011
# mean / median: 1274.27868852459, 1385.0
# p5 / p95: 533.0, 1848.0
#
# #### Distribution of num_assistant_tokens_per_example:
# min / max: 11, 334
# mean / median: 72.36065573770492, 37.0
# p5 / p95: 23.0, 193.0
#
# 0 examples may be over the 4096 token limit, they will be truncated during fine-tuning
# Dataset has ~77731 tokens that will be charged for during training
# By default, you'll train for 3 epochs on this dataset
# By default, you'll be charged for ~233193 tokens
# As of Augest 22, 2023, fine-tuning gpt-3.5-turbo is $0.008 / 1K Tokens.
# This means your total cost for training will be $0.621848 per epoch.
# Waiting for file to be ready...

# %%
finetune_engine.get_current_job()
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-u9T7BF5zRxVX4n5b9Jtbb5cR at 0x2c641fe20> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-u9T7BF5zRxVX4n5b9Jtbb5cR",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1693254044,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-1ZDAvajC6v2ZtAP9hLEIsXRz",
#   "result_files": [],
#   "status": "running",
#   "validation_file": null,
#   "training_file": "file-j1fwmqIAoqZXWZQ8EqwHucXs",
#   "hyperparameters": {
#     "n_epochs": 3
#   },
#   "trained_tokens": null
# }

# %%
ft_llm = finetune_engine.get_finetuned_model(temperature=0.3)

# %% [markdown]
# ## Evaluation
#
# After some time, your model will be done training!
#
# The next step is running our fine-tuned model on our eval dataset again to measure any performance increase.

# %%
from llama_index import ServiceContext
from llama_index.llms import OpenAI
from llama_index.callbacks import OpenAIFineTuningHandler
from llama_index.callbacks import CallbackManager


# Option 1: pass in ft_llm directly into ServiceContext
ft_context = ServiceContext.from_defaults(
    llm=ft_llm,
    context_window=2048,  # limit the context window artifically to test refine process
)

# # Option 2: you can also specify the model name manually
# ft_model_name = "ft:gpt-3.5-turbo-0613:..."
# ft_context = ServiceContext.from_defaults(
#     llm=OpenAI(model=ft_model_name, temperature=0.3),
#     context_window=2048,  # limit the context window artifically to test refine process
# )

# %%
questions = []
with open("eval_questions.txt", "r") as f:
    for line in f:
        questions.append(line.strip())

# %%
from llama_index import VectorStoreIndex

index = VectorStoreIndex.from_documents(documents, service_context=ft_context)

query_engine = index.as_query_engine(similarity_top_k=2)

# %%
contexts = []
answers = []

for question in questions:
    response = query_engine.query(question)
    contexts.append([x.node.get_content() for x in response.source_nodes])
    answers.append(str(response))

# %%
from datasets import Dataset
from ragas import evaluate
from ragas.metrics import answer_relevancy, faithfulness

ds = Dataset.from_dict(
    {
        "question": questions,
        "answer": answers,
        "contexts": contexts,
    }
)

result = evaluate(ds, [answer_relevancy, faithfulness])
print(result)
# Out:
# evaluating with [answer_relevancy]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:49<00:00, 16.34s/it]
# evaluating with [faithfulness]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3/3 [04:04<00:00, 81.44s/it]
# {'ragas_score': 0.8680, 'answer_relevancy': 0.9607, 'faithfulness': 0.7917}

# %% [markdown]
# ## Exploring Differences
#
# Let's quickly compare the differences in responses, to demonstrate that fine tuning did indeed change something.

# %%
from llama_index import VectorStoreIndex

index = VectorStoreIndex.from_documents(documents)

# %%
questions = []
with open("eval_questions.txt", "r") as f:
    for line in f:
        questions.append(line.strip())

# %%
print(questions[12])
# Out:
# What is a key barrier globally for ocean health, governance, and adaptation to climate change, according to the report?

# %% [markdown]
# ### Original

# %%
from llama_index.response.notebook_utils import display_response
from llama_index import ServiceContext
from llama_index.llms import OpenAI


gpt_35_context = ServiceContext.from_defaults(
    llm=OpenAI(model="gpt-3.5-turbo", temperature=0.3),
    context_window=2048,  # limit the context window artifically to test refine process
)

# %%
query_engine = index.as_query_engine(service_context=gpt_35_context)

response = query_engine.query(questions[12])

display_response(response)
# Out:
# **`Final Response:`** A key barrier globally for ocean health, governance, and adaptation to climate change, according to the report, is the availability of technology, knowledge, and financial support, as well as existing governance structures.

# %% [markdown]
# ### Fine-Tuned

# %%
from llama_index import ServiceContext
from llama_index.llms import OpenAI


ft_context = ServiceContext.from_defaults(
    llm=ft_llm,
    context_window=2048,  # limit the context window artifically to test refine process
)

# %%
query_engine = index.as_query_engine(service_context=ft_context)

response = query_engine.query(questions[12])

display_response(response)
# Out:
# **`Final Response:`** The report identifies a broad range of barriers and limits for adaptation to climate change in ecosystems and human systems. These include the availability of technology, knowledge, and financial support, as well as existing governance structures. Existing ocean-governance structures are already facing multi-dimensional, scale-related challenges because of climate change.

# %% [markdown]
# As we can see, the fine-tuned model provides a more thorough response! This lines up with the increased faithfullness score from ragas, since the answer is more representative of the retrieved context.

# %% [markdown]
# ## Conclusion
#
# So, in conclusion, finetuning with only ~61 questions actually helped improve our eval scores!
#
# **answer_relevancy: 0.9725 -> 0.9607**
#
# The answer relevancy dips slightly but it's very small.
#
# **faithfulness: 0.7325 -> 0.7917**
#
# The faithfulness appears to have been improved! This mains the anwers given better fuffil the original question that was asked.
